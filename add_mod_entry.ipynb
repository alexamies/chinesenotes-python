# %% [markdown]
# <a href="https://colab.research.google.com/github/alexamies/chinesenotes-python/blob/master/add_mod_entry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook to add dictionary entries

# %%
import re
import pandas as pd
import numpy as np

# Load lexical units table
colnames = ['id', 'simplified', 'traditional', 'pinyin', 
            'english', 'grammar', 'concept_cn', 'concept_en', 
            'domain_cn', 'domain_en', 'subdomain_cn', 'subdomain_en',
            'image', 'mp3', 'notes', 'headword']
types = {'id': np.uint32, 'simplified': str, 'traditional': str, 
        'pinyin': str, 'english': str, 'grammar': str,
        'concept_cn': str, 'concept_en': str,
        'domain_cn': str, 'domain_en': str, 'subdomain_cn': str,
         'subdomain_en': str, 'image': str, 'mp3': str,
         'notes': str, 'headword': np.uint32}
df = pd.read_csv('https://github.com/alexamies/chinesenotes.com/raw/master/data/cnotes_zh_en_dict.tsv', names=colnames,
                 dtype=types,  sep='\t', comment='#')
# Words with no notes
df.loc[df.notes == '\\N'][:5]
# Out:
#           id simplified traditional       pinyin  \
# 14470  14472         点子          點子       diǎnzi
# 14471  14473         点子          點子       diǎnzi
# 14472  14474        电动机         電動機  diàn dòngjī
# 14476  14478         电钮          電鈕      diànniǔ
# 14478  14480         淀粉          澱粉      diànfěn
#
#                                        english grammar concept_cn concept_en  \
# 14470                                  an idea    noun         \N         \N
# 14471  a spot; a point; a dot; a speck; a drop    noun         \N         \N
# 14472                        an electric motor    noun         \N         \N
# 14476             push button; electric switch    noun         \N         \N
# 14478                                   starch    noun         粮食     Grains
#
#       domain_cn       domain_en subdomain_cn    subdomain_en image mp3 notes  \
# 14470      现代汉语  Modern Chinese           \N              \N    \N  \N    \N
# ...

# %%
#Add a new entry
# Find simplified and pinyin from a traditional text string

#Input
tradArr = ['走', '監', '犯']
english = ['prison escapee']
grammar = ['phrase']
# Concept
empty = '\\N\t\\N'
animal = '动物\tAnimal'
artist = '艺术家\tArtist'
association = '协会\tAssociation'
bird = '鸟\tBird'
book = '书名\tBook Title'
character = '主角\tCharacter'
city = '城市\tCity'
cl = '类\tClass'
clan = '氏\tClan'
color = '颜色\tColor'
company = '公司\tCompany'
compound = '化合物\tCompound'
constellation = '星座\tConstellation'
county = '县\tCounty'
country = '国家\tCountry'
deity = '神\tDeity'
discipline = '学科\tDiscipline'
distilled = '蒸餾酒\tDistilled Beverage'
district = '地区\tDistrict'
dynasty = '朝代\tDynasty'
emperor = '黄帝\tEmperor'
empress = '皇后\tEmpress'
epoch = '世\tEpoch'
family = '科\tFamily'
festival = '节日\tFestival'
fish = '鱼\tFish'
flower = '花\tFlower'
fruit = '水果\tFruit'
gemstone = '宝石\tGemstone'
genus = '属\tGenus'
geo_period = '地质年代\tGeological Period'
given = '姓名\tGiven Name'
heaven = '天\tHeaven'
industry = '产业\tIndustry'
insect = '昆虫\tInsect'
island = '岛\tIsland'
kingdom = '王国\tKingdom'
lake = '湖\tLake'
language_family = '语系\tLanguage Family'
language = '语言\tLanguage'
library = '图书馆\tLibrary'
mineral = '矿物\tMineral'
minority = '民族\tEthnic Group'
monarch = '君主\tMonarch'
monastic = '法师\tMonastic'
mountain = '山\tMountain'
mountain_range = '山脉\tMountain Range'
movie = '电影\tMovie'
newspaper = '报纸\tNewspaper'
np = '国家公园\tNational Park'
order = '目\tOrder'
organization = '团体\tOrganization'
peak = '峰\tPeak'
person = '人\tPerson'
place = '地名\tPlace Name'
plant = '植物\tPlant'
poet = '诗人\tPoet'
politician = '政治家\tPolitician'
posthumous = '谥号\tPosthumous Title'
prefecture = '郡\tPrefecture'
province = '省\tProvince'
publisher = '出版者\tPublisher'
reign = '年号\tReign Name'
river = '水名\tRiver'
scholar = '学者\tScholar'
school = '宗\tSchool'
scientist = '科学家\tScientist'
sect = '派别\tSect'
spice = '调料\tSpice'
state = '州\tState'
subphylum = '亚门\tSubphylum'
surname = '姓氏\tSurname'
temple = '寺院\tTemple'
tian = '天\tDeity'
title = '官名\tOfficial Title'
tree = '树\tTree'
tv_series = '电视剧\tTV Series'
vegetable = '蔬菜\tVegetable'
university = '大学\tUniversity'
warlord = '军阀\tWarlord'
writer = '作者\tAuthor'
concept = [empty]

# Domain
art = '艺术\tArt'
buddhism = '佛教\tBuddhism'
commerce = '商务\tCommerce'
common = '俗语\tCommon Saying'
compsci = '计算机学\tComputer Science'
drama = '戏剧\tDrama'
education = '教育\tEducation'
history = '历史\tHistory'
idiom = '成语\tIdiom'
linguistics = '语言学\tLinguistics'
literary = '文言文\tLiterary Chinese'
literature = '文学\tLiterature'
modern = '现代汉语\tModern Chinese'
places = '地方\tPlaces'
politics = '政治\tPolitics'
proverb = '谚语\tProverb'
domain = [modern]

subdomain = '\\N\t\\N'
#subdomain = '能力\tAbility'
#subdomain = '行为\tActions'
#subdomain = '管理\tAdministration'
#subdomain = '非洲\tAfrica'
#subdomain = '农业\tAgriculture'
#subdomain = '人类学\tAnthropology'
#subdomain = '建筑学\tArchitecture'
#subdomain = '天文\tAstronomy'
#subdomain = '占星术\tAstrology'
#subdomain = '航空\tAviation'
#subdomain = '澳大利亚\tAustralia'
#subdomain = '美丽\tBeauty'
#subdomain = '生物学\tBiology'
#subdomain = '植物学\tBotany'
#subdomain = '书法\tCalligraphy'
#subdomain = '加拿大\tCanada'
#subdomain = '禅宗\tChan'
#subdomain = '变化\tChange'
#subdomain = '特点\tCharacteristic'
#subdomain = '化学\tChemistry'
#subdomain = '中国\tChina'
#subdomain = '中医\tChinese Medicine'
#subdomain = '基督教\tChristianity'
#subdomain = '土木\tCivil Engineering'
#subdomain = '服装\tClothing'
#subdomain = '颜色\tColor'
#subdomain = '通讯\tCommunications'
#subdomain = '比较\tComparison'
#subdomain = '计算机图形\tComputer Graphics'
#subdomain = '状况\tCondition'
#subdomain = '冲突\tConflict'
#subdomain = '儒家\tConfucianism'
#subdomain='容器\tContainer'
#subdomain = '文化\tCulture'
#subdomain = '习俗\tCustoms'
#subdomain = '跳舞\tDancing'
#subdomain = '方言\tDialect'
#subdomain = '灾难\tDisaster'
#subdomain = '戏剧\tDrama'
#subdomain = '地球科学\tEarth Sciences'
#subdomain = '电机工程学\tElectrical Engineering'
#subdomain = '环境\tEnvironment'
#subdomain = '经济\tEconomics'
#subdomain = '教育\tEducation'
#subdomain = '电器\tElectrical Appliances'
#subdomain = '电\tElectricity'
#subdomain = '电子工程\tElectronic Engineering'
#subdomain = '感情\tEmotion'
#subdomain = '英国\tEngland'
#subdomain = '昆虫学\tEntomology'
#subdomain = '欧洲\tEurope'
#subdomain = '家\tFamily'
#subdomain = '火\tFire'
#subdomain = '财会\tFinance and Accounting'
#subdomain = '饮食\tFood and Drink'
#subdomain = '形态\tForm'
#subdomain = '友谊\tFriendship'
#subdomain = '虚词\tFunction Words'
#subdomain = '地理\tGeography'
#subdomain = '地质\tGeology'
#subdomain = '政府\tGovernment'
#subdomain = '几何\tGeometry'
#subdomain = '语法\tGrammar'
#subdomain = '帮助\tHelp'
#subdomain = '健康\tHealth'
#subdomain = '住房\tHousing'
#subdomain = '幽默\tHumor'
#subdomain = '卫生\tHygiene'
#subdomain = '鱼类学\tIchthyology'
#subdomain = '印度\tIndia'
#subdomain = '产业\tIndustry'
#subdomain = '信息\tInformation'
#subdomain = '信息学\tInformation Science'
#subdomain = '信息技术\tInformation Technology'
#subdomain = '回教\tIslam'
#subdomain = '配饰\tJewelry'
#subdomain = '日本\tJapan'
#subdomain = '韩国\tKorea'
#subdomain = '语言\tLanguage'
#subdomain = '法律\tLaw'
#subdomain = '光纤\tLight'
#subdomain = '休闲\tLeisure'
#subdomain = '图书馆学\tLibrary Science'
#subdomain = '生活\tLife'
#subdomain = '逻辑\tLogic'
#subdomain = '法术\tMagic'
#subdomain = '制造业\tManufacturing'
#subdomain  ='武术\tMartial Arts'
#subdomain = '材料科学\tMaterials Science'
#subdomain = '数学\tMathematics'
#subdomain = '测控\tMeasurement and Control'
#subdomain = '机械\tMechanical'
#subdomain = '力学\tMechanics'
#subdomain = '媒体\tMedia'
#subdomain = '医学\tMedicine'
#subdomain = '气象学\tMeteorology'
#subdomain = '军事\tMilitary'
#subdomain = '道德\tMorality'
#subdomain = '活动\tMovement'
#subdomain = '音乐\tMusic'
#subdomain = '神话\tMythology'
#subdomain = '名字\tNames'
#subdomain = '大自然\tNature'
#subdomain = '网络\tNetworking'
#subdomain = '观察\tObservation'
#subdomain = '光学\tOptics'
#subdomain = '有机化学\tOrganic Chemistry'
#subdomain = '鸟类学\tOrnithology'
#subdomain = '组织\tOrganization'
#subdomain = '表演艺术 Performing Arts'
#subdomain = '人\tPeople'
#subdomain = '哲学\tPhilosophy'
#subdomain = '语音学\tPhonetics'
#subdomain = '摄影术\tPhotography'
#subdomain = '物理\tPhysics'
#subdomain = '政治\tPolitics'
#subdomain = '位\tPosition'
#subdomain = '过程\tProcess'
#subdomain = '心理学\tPsychology'
#subdomain = '公安\tPublic Security'
#subdomain = '出版\tPublishing'
#subdomain = '数量\tQuantity'
#subdomain = '研究\tResearch'
#subdomain = '宗教\tReligion'
#subdomain = '规模\tScale'
#subdomain = '科学\tScience'
#subdomain = '交际\tSocial Interaction'
#subdomain = '社会\tSociety'
#subdomain = '社会学\tSocial Science'
#subdomain = '声\tSound'
#subdomain = '航天\tSpace Flight'
#subdomain = '体育\tSport'
#subdomain = '文具\tStationery'
#subdomain = '统计学\tStatistics'
#subdomain = '力气\tStrength'
#subdomain = '唐\tTang'
#subdomain = '道教\tTaoism'
#subdomain = '交通\tTransportation'
#subdomain = '温度\tTemperature'
#subdomain = '思想\tThought'
#subdomain = '时间\tTime'
#subdomain = '技术\tTechnology'
#subdomain = '工具\tTools'
#subdomain = '美国\tUnited States'
#subdomain = '越南\tVietnam'
#subdomain = '暴力\tViolence'
#subdomain = '船\tWatercraft'
#subdomain = '水\tWater'
#subdomain = '武器\tWeapons'
#subdomain = '财富\tWealth'
#subdomain = '写作\tWriting'
#subdomain = '工作\tWork'
#subdomain = '动物学\tZoology'
note = [''
       ]

# Generated
luid = df.count()[0] + 2 #np.amax(df.index.values)[0] + 1
print(luid)
headword = luid
traditional = ''
simplified = ''
pinyin = ''
for t in tradArr:
  sDF = df[df.traditional == t]['simplified']
  tDF = df[df.traditional == t]['traditional']
  pDF = df[df.traditional == t]['pinyin']
  if sDF.count() > 0:
    simplified += sDF.iloc[0]
    traditional +=tDF.iloc[0]
    pinyin += pDF.iloc[0] + ' '
  else:
    sDF = df[df.simplified == t]['simplified']
    tDF = df[df.simplified == t]['simplified']
    pDF = df[df.simplified == t]['pinyin']
    if sDF.count() > 0:
      simplified += sDF.iloc[0]
      traditional += sDF.iloc[0]
      pinyin += pDF.iloc[0] + ' '
    else:
      print(f'{t} not found')
pinyin.strip()
trad = traditional
if simplified == traditional:
  trad = '\\N'
pinyin = pinyin.replace(' ', '')
print(simplified)
print(trad)
print(pinyin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9471f5001010> in <module>()
#     268
#     269 # Generated
# --> 270 luid = df.count()[0] + 2 #np.amax(df.index.values)[0] + 1
#     271 print(luid)
#     272 headword = luid
#
# NameError: name 'df' is not defined

# %%
# Input - 
#pinyin = 'tài' # override for variant pronounciations

# Modify references as needed
# Repeat this for each lexical unit. See abbreviations.html for the abbreviations.
#bscd = 'BCSD '%s'' % traditional
cedict = f"CC-CEDICT '{traditional}'"
guoyu = f"Guoyu '{traditional}'"
wiki = f"Wikipedia '{traditional}'"
# add more references as needed
refArr = [[cedict, guoyu, wiki]]

# Print entries to standard out
for i in range(len(english)):
  luid = headword + i
  ref = ''
  for r in refArr[i]:
    if r != '':
      ref += r + '; '
  ref = re.sub('; $', '', ref)
  if ref != '':
    ref = f'({ref})'

  notes = '%s%s' % (note[i], ref)
  print(f'{luid}\t{simplified}\t{trad}\t{pinyin}\t{english[i]}\t{grammar[i]}\t{concept[i]}\t{domain[i]}\t{subdomain}\t\\N\t\\N\t{notes}\t{headword}\n')
